# %%
import pandas as pd

# %%
data = pd.read_csv("dota_heroes728.csv")
data
# Out:
#               Hero  Strength   Agility Intelligence  Health_base  Health_lvl1  \
# 0          Abaddon    23 + 3  23 + 1.5       18 + 2          200          660
# 1        Alchemist  25 + 2.7  22 + 1.5     25 + 1.8          200          700
# 2              Axe  25 + 3.4  20 + 2.2     18 + 1.6          200          700
# 3      Beastmaster  23 + 2.9  18 + 1.6     16 + 1.9          200          660
# 4       Brewmaster  23 + 3.7    19 + 2     15 + 1.6          200          660
# ..             ...       ...       ...          ...          ...          ...
# 115        Warlock    26 + 3    10 + 1     25 + 3.1          200          720
# 116     Windranger    18 + 3  17 + 1.4     18 + 3.6          200          560
# 117  Winter_Wyvern  24 + 2.6  16 + 1.9     26 + 3.6          200          680
# 118   Witch_Doctor  18 + 2.3  13 + 1.4     22 + 3.3          200          560
# 119           Zeus  19 + 2.1  11 + 1.2     22 + 3.3          200          580
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 52 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Hero                120 non-null    object
#  1   Strength            120 non-null    object
#  2   Agility             120 non-null    object
#  3   Intelligence        120 non-null    object
#  4   Health_base         120 non-null    int64
#  5   Health_lvl1         120 non-null    int64
#  6   Health_lvl15        120 non-null    int64
#  7   Health_lvl25        120 non-null    int64
#  8   Health_lvl30        120 non-null    int64
#  9   Health regen_base   120 non-null    float64
#  10  Health regen_lvl1   120 non-null    float64
#  11  Health regen_lvl15  120 non-null    float64
#  12  Health regen_lvl25  120 non-null    float64
#  13  Health regen_lvl30  120 non-null    float64
#  14  Mana_base           120 non-null    int64
# ...

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Health_base'}>,
#         <AxesSubplot:title={'center':'Health_lvl1'}>,
#         <AxesSubplot:title={'center':'Health_lvl15'}>,
#         <AxesSubplot:title={'center':'Health_lvl25'}>,
#         <AxesSubplot:title={'center':'Health_lvl30'}>,
#         <AxesSubplot:title={'center':'Health regen_base'}>],
#        [<AxesSubplot:title={'center':'Health regen_lvl1'}>,
#         <AxesSubplot:title={'center':'Health regen_lvl15'}>,
#         <AxesSubplot:title={'center':'Health regen_lvl25'}>,
#         <AxesSubplot:title={'center':'Health regen_lvl30'}>,
#         <AxesSubplot:title={'center':'Mana_base'}>,
#         <AxesSubplot:title={'center':'Mana_lvl1'}>],
#        [<AxesSubplot:title={'center':'Mana_lvl15'}>,
#         <AxesSubplot:title={'center':'Mana_lvl25'}>,
#         <AxesSubplot:title={'center':'Mana_lvl30'}>,
#         <AxesSubplot:title={'center':'Mana regen_base'}>,
#         <AxesSubplot:title={'center':'Mana regen_lvl1'}>,
# ...

# %%
data.describe()
# Out:
#        Health_base  Health_lvl1  Health_lvl15  Health_lvl25  Health_lvl30  \
# count        120.0   120.000000    120.000000    120.000000    120.000000
# mean         200.0   626.000000   1375.333333   1915.833333   2185.000000
# std            0.0    60.005602    206.836652    324.048921    383.537274
# min          200.0   480.000000    960.000000   1260.000000   1400.000000
# 25%          200.0   580.000000   1220.000000   1660.000000   1880.000000
# 50%          200.0   620.000000   1350.000000   1860.000000   2140.000000
# 75%          200.0   660.000000   1525.000000   2145.000000   2460.000000
# max          200.0   780.000000   2020.000000   2940.000000   3400.000000
#
#        Health regen_base  Health regen_lvl1  Health regen_lvl15  \
# count         120.000000         120.000000          120.000000
# mean            0.341667           2.471667            6.255167
# std             0.679790           0.772661            1.306965
# ...
